# %% [markdown]
# <a href="https://colab.research.google.com/github/samtam0714/Time-Series-ARIMA--COVID19-/blob/master/TS_arima_covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas import Series
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from pandas import datetime
df = pd.read_csv('./covid-19.csv')
df
# Out:
#              Date Country/Region Province/State  ...  Confirmed  Recovered  Deaths
# 0      2020-01-22    Afghanistan            NaN  ...        0.0        0.0     0.0
# 1      2020-01-23    Afghanistan            NaN  ...        0.0        0.0     0.0
# 2      2020-01-24    Afghanistan            NaN  ...        0.0        0.0     0.0
# 3      2020-01-25    Afghanistan            NaN  ...        0.0        0.0     0.0
# 4      2020-01-26    Afghanistan            NaN  ...        0.0        0.0     0.0
# ...           ...            ...            ...  ...        ...        ...     ...
# 24811  2020-04-20       Zimbabwe            NaN  ...       25.0        2.0     3.0
# 24812  2020-04-21       Zimbabwe            NaN  ...       28.0        2.0     3.0
# 24813  2020-04-22       Zimbabwe            NaN  ...       28.0        2.0     4.0
# 24814  2020-04-23       Zimbabwe            NaN  ...       28.0        2.0     4.0
# ...

# %%
df['Country/Region'].value_counts()
# Out:
# China             3102
# Canada            1410
# United Kingdom    1034
# France            1034
# Australia          752
#                   ...
# Uganda              94
# Ethiopia            94
# Ireland             94
# Georgia             94
# Chile               94
# Name: Country/Region, Length: 185, dtype: int64

# %%
dfDate = df.groupby(["Date"])[['Confirmed', 'Deaths', 'Recovered']].sum().reset_index()

# %%
dfDate[10:]
# Out:
#           Date  Confirmed    Deaths  Recovered
# 10  2020-02-01    12038.0     259.0      284.0
# 11  2020-02-02    16787.0     362.0      472.0
# 12  2020-02-03    19881.0     426.0      623.0
# 13  2020-02-04    23892.0     492.0      852.0
# 14  2020-02-05    27635.0     564.0     1124.0
# ..         ...        ...       ...        ...
# 89  2020-04-20  2471247.0  169985.0   645738.0
# 90  2020-04-21  2548091.0  176582.0   679819.0
# 91  2020-04-22  2623049.0  183064.0   709694.0
# 92  2020-04-23  2707728.0  190857.0   738486.0
# 93  2020-04-24  2809977.0  197004.0   789069.0
#
# [84 rows x 4 columns]

# %%
dfCountry = df.groupby(["Country/Region"])[['Confirmed', 'Deaths', 'Recovered']].sum().reset_index()

# %%
dfCountry
# Out:
#          Country/Region  Confirmed  Deaths  Recovered
# 0           Afghanistan    17827.0   553.0     1598.0
# 1               Albania    13401.0   645.0     5552.0
# 2               Algeria    52667.0  6914.0    14989.0
# 3               Andorra    17443.0   711.0     3311.0
# 4                Angola      490.0    54.0       92.0
# ..                  ...        ...     ...        ...
# 180  West Bank and Gaza     9138.0    55.0     1477.0
# 181      Western Sahara      106.0     0.0       10.0
# 182               Yemen       15.0     0.0        1.0
# 183              Zambia     1390.0    44.0      528.0
# 184            Zimbabwe      473.0    71.0       18.0
#
# [185 rows x 4 columns]

# %%
recovered = dfDate[['Date', 'Recovered']]
for index, row in recovered.iterrows():
    if row['Recovered'] is None:
        row['Recovered'] = 0.0
recovered[10:]
# Out:
#           Date  Recovered
# 10  2020-02-01      284.0
# 11  2020-02-02      472.0
# 12  2020-02-03      623.0
# 13  2020-02-04      852.0
# 14  2020-02-05     1124.0
# ..         ...        ...
# 89  2020-04-20   645738.0
# 90  2020-04-21   679819.0
# 91  2020-04-22   709694.0
# 92  2020-04-23   738486.0
# 93  2020-04-24   789069.0
#
# [84 rows x 2 columns]

# %%
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
f, ax = plt.subplots(figsize=(20, 150))
data = df[['Country/Region','Confirmed','Recovered','Deaths']]
data.sort_values('Confirmed',ascending=False,inplace=True)
sns.set_color_codes("pastel")
sns.barplot(x="Confirmed", y="Country/Region", data=data,label="Confirmed", color="r")

sns.set_color_codes("muted")
sns.barplot(x="Recovered", y="Country/Region", data=data, label="Recovered", color="g")


# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 80000), ylabel="",xlabel="Cases")
sns.despine(left=True, bottom=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
death = dfDate[['Date', 'Deaths']]

for index, row in death.iterrows():
    if row['Deaths'] is None:
        row['Deaths'] = 0.0
death[:10]
# Out:
#          Date  Deaths
# 0  2020-01-22    17.0
# 1  2020-01-23    18.0
# 2  2020-01-24    26.0
# 3  2020-01-25    42.0
# 4  2020-01-26    56.0
# 5  2020-01-27    82.0
# 6  2020-01-28   131.0
# 7  2020-01-29   133.0
# 8  2020-01-30   171.0
# 9  2020-01-31   213.0

# %%
confirmed = dfDate[['Date', 'Confirmed']]
for index, row in confirmed.iterrows():
    if row['Confirmed'] is None:
        row['Confirmed'] = 0.0
confirmed[:10]
# Out:
#          Date  Confirmed
# 0  2020-01-22      555.0
# 1  2020-01-23      654.0
# 2  2020-01-24      941.0
# 3  2020-01-25     1434.0
# 4  2020-01-26     2118.0
# 5  2020-01-27     2927.0
# 6  2020-01-28     5578.0
# 7  2020-01-29     6166.0
# 8  2020-01-30     8234.0
# 9  2020-01-31     9927.0

# %%
plt.figure(figsize=(15,5))
plt.plot(recovered["Recovered"],marker="*",color='g',label='Recovered')
plt.plot(death["Deaths"],marker="o",color='r',label='Deaths')
plt.legend()

# %%
from pandas import read_csv
from matplotlib import pyplot

confirmed.plot()
pyplot.show()

# %%
#Autocorrelation Graphs
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(death['Deaths'].diff().dropna(), lags=10, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(death['Deaths'].diff().dropna(), lags=10, ax=ax2)
plt.show()

# %%
import itertools
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
#Script to find Optimal Parameters
import sys
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
tmp_model = None
best_mdl = None
for param in pdq:
 for param_seasonal in seasonal_pdq:
     try:
         tmp_mdl = sm.tsa.statespace.SARIMAX(np.asanyarray(death['Deaths']),
                                                order = param,
                                                seasonal_order = param_seasonal,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True)
         res = tmp_mdl.fit()
         if res.aic < best_aic:
             best_aic = res.aic
             best_pdq = param
             best_seasonal_pdq = param_seasonal
             best_mdl = tmp_mdl
     except:
         continue
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:993: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:981: UserWarning:
#
# Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning:
#
# ...

# %%
#Print Optimal Model Parameters
print("Best SARIMAX{}x{} model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
# Out:
# Best SARIMAX(1, 1, 0)x(0, 1, 1, 12) model - AIC:1317.88510776825

# %%
mod = sm.tsa.statespace.SARIMAX(np.asanyarray(death['Deaths']),
                                order=(1, 1, 0),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9665      0.026     37.451      0.000       0.916       1.017
# ma.S.L12      -0.6520      0.228     -2.863      0.004      -1.098      -0.206
# sigma2      6.863e+05   6.64e+04     10.342      0.000    5.56e+05    8.16e+05
# ...

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred_uc = results.get_forecast(steps=50)
pred_ci = pred_uc.conf_int()

# %%
pred_ci[10:]
# Out:
# array([[238323.98797074, 302837.73670652],
#        [240651.95499987, 312906.88152529],
#        [242674.66375799, 323325.05118997],
#        [244910.58020701, 334499.46432777],
#        [247422.68884942, 346402.70099031],
#        [250189.3683653 , 358939.62257644],
#        [252622.50240921, 371462.40865637],
#        [253537.760805  , 382737.78501979],
#        [254713.22729513, 394503.13888955],
#        [255370.48796191, 405945.82001901],
#        [256655.33881751, 418182.50187713],
#        [257707.87614199, 430328.25430431],
#        [258904.49559285, 442737.76408784],
#        [259480.5093384 , 454627.33896376],
#        [259848.14193859, 466766.76520591],
#        [260500.42947906, 479588.76832551],
#        [261481.85178722, 493084.50747458],
#        [262757.70669042, 507171.99683419],
#        [263730.76798857, 521212.59534649],
#        [263210.37726005, 533979.42423273],
#        [262970.24278574, 547214.31111036],
#        [262228.92215797, 560107.69697822],
# ...

# %%
#Autocorrelation Graphs
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(confirmed['Confirmed'].diff().dropna(), lags=10, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(confirmed['Confirmed'].diff().dropna(), lags=10, ax=ax2)
plt.show()

# %%
import itertools
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
#Script to find Optimal Parameters
import sys
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
tmp_model = None
best_mdl = None
for param in pdq:
 for param_seasonal in seasonal_pdq:
     try:
         tmp_mdl = sm.tsa.statespace.SARIMAX(np.asanyarray(confirmed['Confirmed']),
                                                order = param,
                                                seasonal_order = param_seasonal,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True)
         res = tmp_mdl.fit()
         if res.aic < best_aic:
             best_aic = res.aic
             best_pdq = param
             best_seasonal_pdq = param_seasonal
             best_mdl = tmp_mdl
     except:
         continue
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:993: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:981: UserWarning:
#
# Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# ...

# %%
#Print Optimal Model Parameters
print("Best SARIMAX{}x{} model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
# Out:
# Best SARIMAX(1, 1, 1)x(1, 1, 1, 12) model - AIC:1671.8726727038663

# %%
mod = sm.tsa.statespace.SARIMAX(np.asanyarray(confirmed['Confirmed']),
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results2 = mod.fit()
print(results2.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0170      0.020     50.208      0.000       0.977       1.057
# ma.L1         -0.2159      0.194     -1.112      0.266      -0.596       0.165
# ar.S.L12       0.3040      0.240      1.264      0.206      -0.167       0.775
# ma.S.L12      -1.2582      0.094    -13.373      0.000      -1.443      -1.074
# sigma2      6.109e+07   1.75e-09   3.49e+16      0.000    6.11e+07    6.11e+07
# ...

# %%
results2.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
#Autocorrelation Graphs
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(recovered['Recovered'].diff().dropna(), lags=10, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(recovered['Recovered'].diff().dropna(), lags=10, ax=ax2)
plt.show()

# %%
import itertools
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
#Script to find Optimal Parameters
import sys
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
tmp_model = None
best_mdl = None
for param in pdq:
 for param_seasonal in seasonal_pdq:
     try:
         tmp_mdl = sm.tsa.statespace.SARIMAX(np.asanyarray(recovered['Recovered']),
                                                order = param,
                                                seasonal_order = param_seasonal,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True)
         res = tmp_mdl.fit()
         if res.aic < best_aic:
             best_aic = res.aic
             best_pdq = param
             best_seasonal_pdq = param_seasonal
             best_mdl = tmp_mdl
     except:
         continue
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:993: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:981: UserWarning:
#
# Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# ...

# %%
#Print Optimal Model Parameters
print("Best SARIMAX{}x{} model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
# Out:
# Best SARIMAX(1, 1, 1)x(1, 1, 0, 12) model - AIC:1578.4074500048464

# %%
mod = sm.tsa.statespace.SARIMAX(np.asanyarray(confirmed['Confirmed']),
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results3 = mod.fit()
print(results3.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9793      0.026     37.538      0.000       0.928       1.030
# ma.L1         -0.0907      0.168     -0.539      0.590      -0.421       0.239
# ar.S.L12      -0.5730      0.155     -3.707      0.000      -0.876      -0.270
# sigma2      6.109e+07   9.99e-10   6.11e+16      0.000    6.11e+07    6.11e+07
# ...
